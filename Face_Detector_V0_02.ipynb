# %% [markdown]
# <a href="https://colab.research.google.com/github/oky15net/Face-Detector/blob/main/Face_Detector_V0_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
# <font color="#ffffff"><font size="6"><u><b>Ai Pendeteksi Wajah</b></u>
#
#
# `Terakhir diperbarui : 27 Mei 2023 | 15:00 PM WIB INDONESIA`
# ### `Okto Ramadhan`
# ---
# Thanks to Chatgpt, berkat jasa nya saya cuma tinggal nyalin code

# %% [markdown]
# # **FACE DETECTOR WITH OPEN CV**

# %% [markdown]
# ### ***SETTING CONFIG & UPLOAD PHOTO***

# %%
# @markdown ### **Import Config (WAJIB CENTANG SEMUA)**
# @markdown > Human : Kalo wajib kenapa dikasih opsi memilih bwang??
# @markdown > Oktooo : Biar Keren Dek
ImportOpenCv = True # @param {type:'boolean'}
# @markdown > cv2 adalah singkatan dari OpenCV (Open Source Computer Vision Library) Library ini menyediakan berbagai fungsi dan algoritma untuk memanipulasi gambar dan video, termasuk pendeteksian objek seperti wajah
ImportNumpy = True # @param {type:'boolean'}
# @markdown > #numpy adalah library yang sering digunakan dalam pemrosesan data numerik. Di sini, kita mengimpor numpy untuk digunakan dalam beberapa operasi pada gambar.
if ImportOpenCv:
  import cv2
  import time
  from tqdm import tqdm
  print("[1;32mImport OpenCv...")

for i in tqdm(range(5)):
    # Simulasi eksekusi tugas
    time.sleep(0.5)

if ImportNumpy :
  import numpy as np
  print("[1;32mImport Numpy...")

for i in tqdm(range(5)):
    # Simulasi eksekusi tugas
    time.sleep(0.5)

print("[1;32mImport File Telah Selesai")
time.sleep(1)
print("[1;32m\nSILAHKAN UPLOAD PHOTO LU DISNI !")





#@markdown ### **<----  UPLOAD PHOTO LU DISANA**

from google.colab import files 
#mengimpor modul files dari paket google.colab. 
#Modul ini menyediakan fungsi untuk mengunggah dan mengunduh file dalam lingkungan Google Colab.

uploaded = files.upload() #digunakan untuk mengunggah file dari komputer Anda ke Google Colab. 
#Setelah mengeksekusi baris ini, Anda akan melihat tampilan untuk memilih file dari komputer Anda dan mengunggahnya ke sesi Google Colab.

print("[1;32mPhoto Telah berhasil TerUpload, Silahkan Lanjut Step Berikutnya")
# Out:
# Import OpenCv...
# 100%|██████████| 5/5 [00:02<00:00,  1.99it/s]
# Import Numpy...
# 100%|██████████| 5/5 [00:02<00:00,  1.99it/s]
# Import File Telah Selesai
#
# SILAHKAN UPLOAD PHOTO LU DISNI !
#      <input type="file" id="files-c2ad715b-f1f3-4f2a-881d-ad0559b8b921" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2ad715b-f1f3-4f2a-881d-ad0559b8b921">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...

# %% [markdown]
# ### **MEMPROSES GAMBAR & MENAMPILKAN HASIL**

# %%
image_path = next(iter(uploaded))
#digunakan untuk mendapatkan path (lokasi) gambar yang telah diunggah.
#uploaded artinya dictionary yang berisi file yang diunggah, 
#dan next(iter()) digunakan untuk mendapatkan path dari file yang pertama kali diunggah.
print("[1;32mMencari Lokasi Gambar...")
for i in tqdm(range(5)):
    # Simulasi eksekusi tugas
    time.sleep(0.5)

image = cv2.imread(image_path)
#digunakan untuk membaca gambar dari path yang diberikan. 
#Fungsi imread() mengembalikan gambar dalam bentuk matriks piksel.
print("[1;32mMembaca Gambar...")
for i in tqdm(range(3)):
    # Simulasi eksekusi tugas
    time.sleep(0.5)


face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#digunakan untuk membuat objek detektor wajah. 
#Kode cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'merujuk pada path file XML yang berisi informasi 
#tentang deteksi wajah menggunakan metode Haar cascades. 
#File ini biasanya disertakan dengan instalasi OpenCV.


faces = face_cascade.detectMultiScale(image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
#face_cascade.detectMultiScale(image, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30)) digunakan untuk mendeteksi wajah dalam gambar. 
#Metode detectMultiScale memerlukan parameter gambar yang akan dianalisis. 
#Parameter lainnya adalah scaleFactor, minNeighbors, dan minSize yang mengatur parameter untuk proses deteksi wajah. 
#Hasil deteksi wajah akan disimpan dalam variabel faces.

print("[1;32mMembuat Detector Wajah")
for i in tqdm(range(4)):
    # Simulasi eksekusi tugas
    time.sleep(0.5)

for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
    #Melalui perulangan for, kita iterasi melalui setiap wajah yang dideteksi dalam faces
    #cv2.rectangle() digunakan untuk menggambar kotak di sekitar wajah. 
    #Parameter pertama adalah gambar asli yang akan dimodifikasi. 
    #Parameter kedua dan ketiga adalah titik koordinat sudut kiri atas kotak yang akan digambar. 
    #Parameter keempat adalah titik koordinat sudut kanan bawah kotak. 
    #Parameter kelima adalah warna kotak dalam format BGR, dengan (0, 255, 0) menghasilkan warna hijau. 
    #Parameter keenam adalah ketebalan garis kotak.
print("[1;32mMembuat Kotak Pada Wajah")
for i in tqdm(range(6)):
    # Simulasi eksekusi tugas
    time.sleep(0.5)

FindImagee = True
NextStep = False

if FindImagee:
    valid_input = False
    while not valid_input:
        user_input = input("Masukkan kata 'okto ganteng' untuk melanjutkan: ")
        if user_input.lower() == "okto ganteng":
            valid_input = True
            NextStep = True
            print("Melanjutkan eksekusi kode program...")
            # ... Kode selanjutnya ...
        else:
            print("anda, ngeyel. Coba lagi...")
else:
    print("NextStep adalah False. Eksekusi kode program dihentikan.")


if NextStep:
    from google.colab.patches import cv2_imshow
#from google.colab.patches import cv2_imshow mengimpor fungsi cv2_imshow dari google.colab.patches. 
#Fungsi ini adalah pengganti dari cv2.imshow() yang tidak didukung langsung di Google Colab.
    cv2_imshow(image)
#cv2_imshow(image) digunakan untuk menampilkan gambar image di output notebook Google Colab.
# Out:
# Mencari Lokasi Gambar...
# 100%|██████████| 5/5 [00:02<00:00,  1.98it/s]
# Membaca Gambar...
# 100%|██████████| 3/3 [00:01<00:00,  1.99it/s]
# Membuat Detector Wajah
# 100%|██████████| 4/4 [00:02<00:00,  1.99it/s]
# Membuat Kotak Pada Wajah
# 100%|██████████| 6/6 [00:03<00:00,  1.99it/s]
# Masukkan kata 'okto ganteng' untuk melanjutkan: okto ganteng
# Melanjutkan eksekusi kode program...
# <PIL.Image.Image image mode=RGB size=799x480 at 0x7F778D3FDC90>

# %% [markdown]
# # **VIDEO FACE DETECTOR**

# %% [markdown]
# **MEMPERSIAPKAN DATA**
